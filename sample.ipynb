# %%
# !ls -l -h data/
# Out:
# total 77M
# -rw-r--r-- 1 jovyan users  36M Nov 12 17:54 operation_round1_new.csv.xz
# -rw-r--r-- 1 jovyan users  29M Nov 12 17:54 operation_train_new.csv.xz
# -rw-r--r-- 1 jovyan users 8.4K Nov 12 17:54 submit_example.csv.xz
# -rw-r--r-- 1 jovyan users  11K Nov 12 17:54 tag_train_new.csv.xz
# -rw-r--r-- 1 jovyan users 4.6M Nov 12 17:54 transaction_round1_new.csv.xz
# -rw-r--r-- 1 jovyan users 7.3M Nov 12 17:54 transaction_train_new.csv.xz

# %%
import pandas as pd

# %%
# %%time
operation_train = pd.read_csv('data/operation_train_new.csv.xz', compression='xz')
# 需要下采样或者只读取少部分数据请使用 skiprows, nrows 参数
print(operation_train.shape)
# Out:
# (1460843, 20)
# CPU times: user 10.2 s, sys: 236 ms, total: 10.5 s
# Wall time: 10.5 s

# %%
operation_train.sample(6).T
# Out:
#                         770729            335252            758549  \
# UID                      61652             21845             64946
# day                         25                 2                 8
# mode          acfaded7e04e7ba0  c8741ce15ceac2a4  79f8b86938180c3c
# success                      1                 1               NaN
# time                  14:14:35          12:12:04          16:46:21
# os                         102               102               200
# version                  7.0.9             7.0.5               NaN
# device1       d2cf44cec09806cc  d2cf44cec09806cc               NaN
# device2              VIVO Y55L         VIVO Y85A               NaN
# device_code1  41263416034a67cc  72651a6b623f336c               NaN
# device_code2  d78553bd227b9436  269652eec289ae18               NaN
# device_code3               NaN               NaN               NaN
# mac1                       NaN               NaN               NaN
# ...
